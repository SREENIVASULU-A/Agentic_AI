# %% [markdown]
# agentic-stock-ai/
# │
# ├── agents.py
# ├── tasks.py
# ├── tools.py
# ├── crew.py
# ├── main.py
# ├── requirements.txt
# └── .env
#
# crewai
# langchain
# langchain-groq
# python-dotenv
# yfinance
# pandas
# pandas-ta
# duckduckgo-search

# %%
# Upload or create requirements.txt in your workspace, then run:
# %pip install -r requirements.txt

# %%
# %sh ls /dbfs

# %% [markdown]
# #  HIGH-LEVEL AGENTIC ARCHITECTURE (CrewAI)
#
# # ```
# # Goal: Analyze stock for future (6–24 months)
#
# ##Planner Agent
# #    |
# ###   |-- Sentiment Agent (positive / negative)
# ###  |-- Fundamental Agent (financial metrics)
# ###   |-- Technical Agent (trend & indicators)
# ###  |
# ### Critic Agent (checks conflicts & risks)
# ###    |
# ###Decision Agent (final outlook + probability)
# ### ```
#
# # ---
#
# # # 🛠️ TOOLS & APIS REQUIRED (MOSTLY FREE)
#
# # ## 1️⃣ Core Tools (Mandatory)
#
# ### | Tool                  | Purpose             |
# ### | --------------------- | ------------------- |
# ### | **Python 3.10+**      | Runtime             |
# ### | **CrewAI**            | Agent orchestration |
# ### | **LangChain**         | LLM interface       |
# ### | **Pandas**            | Data processing     |
# ### | **yfinance**          | Stock prices        |
# ### | **duckduckgo-search** | News (free)         |
#
# ### ---
#
# ## 2️⃣ LLM APIs (Choose ONE – FREE options)
#
# # ### ✅ Recommended (FREE)
#
# # | Provider                     | Use            |
# # | ---------------------------- | -------------- |
# # | **Groq (LLaMA 3 / Mixtral)** | Fast reasoning |
# # | **Google Gemini**            | Analysis       |
#
# # 👉 I’ll show code using **Groq (FREE & fast)**
#
# # ---
#
# # ## 3️⃣ Market Data APIs (FREE)
#
# # | Data         | Source        |
# # | ------------ | ------------- |
# # | Prices       | Yahoo Finance |
# # | Fundamentals | Yahoo Finance |
# # | News         | DuckDuckGo    |
#
# # ---
#
# # # 📁 PROJECT STRUCTURE (CLEAN)
#
# # ```
# # agentic-stock-ai/
# # │
# # ├── agents.py
# # ├── tasks.py
# # ├── tools.py
# # ├── crew.py
# # ├── main.py
# # ├── requirements.txt
# # └── .env
# # ```
#
# # ---
#
# # # ⚙️ STEP 1: INSTALL DEPENDENCIES
#
# # ### `requirements.txt`
#
# # ```txt
# # crewai
# # langchain
# # langchain-groq
# # python-dotenv
# # yfinance
# # pandas
# # pandas-ta
# # duckduckgo-search
#
# # 🔑 STEP 2: API KEYS (FREE)
#
# ### Groq API (FREE)
#
# <!-- 1. Go to **Groq Cloud**
# 2. Create account
# 3. Generate API key -->
#
# # 🧰 STEP 3: CREATE TOOLS (Data Functions)
#
# ### `tools.py`
#
# <!-- ```python
# import yfinance as yf
# import pandas_ta as ta
# from duckduckgo_search import DDGS -->
# # 🤖 STEP 4: DEFINE AGENTS
#
# ### `agents.py`
#
# <!-- ```python
# from crewai import Agent
# from langchain_groq import ChatGroq
# # 📋 STEP 5: DEFINE TASKS
#
# ### `tasks.py`
#
# ```python
# from crewai import Task
# from tools import get_news, get_fundamentals, get_technical -->
# # 🧠 STEP 6: CREATE THE CREW
#
# ### `crew.py`
# # ▶️ STEP 7: RUN THE AGENTIC AI
#
# ### `main.py`
#
# ```python
# from crew import run_crew
#
# if __name__ == "__main__":
#     stock = "TATAMOTORS.NS"
#     result = run_crew(stock)
#     print(result)

# %% [markdown]
# # 🆓 FREE ACCESS SUMMARY (FINAL)
#
# ### AI
#
# * Groq LLaMA-3 → FREE
# * Gemini → FREE
#
# ### Data
#
# * Yahoo Finance → FREE
# * DuckDuckGo → FREE
#
# ### Infra
#
# * Local machine
# * Google Colab → FREE
