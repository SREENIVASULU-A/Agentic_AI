# %% [markdown]
# agentic-stock-ai/
# │
# ├── agents.py
# ├── tasks.py
# ├── tools.py
# ├── crew.py
# ├── main.py
# ├── requirements.txt
# └── .env
#
# crewai
# langchain
# langchain-groq
# python-dotenv
# yfinance
# pandas
# pandas-ta
# duckduckgo-search

# %%
# Upload or create requirements.txt in your workspace, then run:
# %pip install -r requirements.txt

# %%
# %sh ls /dbfs
